# %% [markdown]
# # Some run with system

# %%
# %load_ext autoreload
# %autoreload 1

# %%
import sys
import subprocess
    
print sys.executable
# Out:
# D:\tools\python2\python.exe

# %%
# install some modules
str_module = 'sql pandas mpld3 vtk plotly scikits ipywidgets unqlite'
modules = str_module.split(' ')
for i in modules:
    p = subprocess.Popen(['pip.exe','install', i], stdout=subprocess.PIPE)
    print p.communicate()[0]
# Out:
# Requirement already satisfied (use --upgrade to upgrade): sql in d:\tools\python2\lib\site-packages
#
# Requirement already satisfied (use --upgrade to upgrade): pandas in d:\tools\python2\lib\site-packages
# Requirement already satisfied (use --upgrade to upgrade): pytz>=2011k in d:\tools\python2\lib\site-packages (from pandas)
# Requirement already satisfied (use --upgrade to upgrade): python-dateutil in d:\tools\python2\lib\site-packages (from pandas)
# Requirement already satisfied (use --upgrade to upgrade): numpy>=1.7.0 in d:\tools\python2\lib\site-packages (from pandas)
# Requirement already satisfied (use --upgrade to upgrade): six>=1.5 in d:\tools\python2\lib\site-packages (from python-dateutil->pandas)
#
# Requirement already satisfied (use --upgrade to upgrade): mpld3 in d:\tools\python2\lib\site-packages
#
# Collecting vtk
#
# Requirement already satisfied (use --upgrade to upgrade): plotly in d:\tools\python2\lib\site-packages
# Requirement already satisfied (use --upgrade to upgrade): pytz in d:\tools\python2\lib\site-packages (from plotly)
# Requirement already satisfied (use --upgrade to upgrade): six in d:\tools\python2\lib\site-packages (from plotly)
# Requirement already satisfied (use --upgrade to upgrade): requests in d:\tools\python2\lib\site-packages (from plotly)
#
# Collecting scikits
#
# Collecting ipywidgets
#
# Collecting unqlite
#   Downloading unqlite-0.2.0.tar.gz (527kB)
# Building wheels for collected packages: unqlite
#   Running setup.py bdist_wheel for unqlite
#   Complete output from command D:\tools\python2\python.exe -c "import setuptools;__file__='c:\\users\\cpu101~1\\appdata\\local\\temp\\pip-build-vsll6e\\unqlite\\setup.py';exec(compile(open(__file__).read().replace('\r\n', '\n'), __file__, 'exec'))" bdist_wheel -d c:\users\cpu101~1\appdata\local\temp\tmpj1vxo8pip-wheel-:
#   running bdist_wheel
#   running build
#   running build_py
#   Status: Preprocessing c:\users\cpu101~1\appdata\local\temp\tmpvd1uzv.h
#   Status: gcc -E -U __GNUC__ -dD "-Dinline=" "-D__inline__=" "-D__extension__=" "-D_Bool=uint8_t" "-D__const=const" "-D__asm__(x)=" "-D__asm(x)=" "-DCTYPESGEN=1" c:\users\cpu101~1\appdata\local\temp\tmpvd1uzv.h
#   Status: Parsing c:\users\cpu101~1\appdata\local\temp\tmpvd1uzv.h
#   Status: Processing description list.
#   Warning: Could not load library "unqlite". Okay, I'll try to load it at runtime instead.
#   Warning: Could not parse macro "#define STRUCT_TM_TO_SYTM(pTM,pSYTM) ( pSYTM ) -> tm_hour = ( pTM ) -> tm_hour ; ( pSYTM ) -> tm_min = ( pTM ) -> tm_min ; ( pSYTM ) -> tm_sec = ( pTM ) -> tm_sec ; ( pSYTM ) -> tm_mon = ( pTM ) -> tm_mon ; ( pSYTM ) -> tm_mday = ( pTM ) -> tm_mday ; ( pSYTM ) -> tm_year = ( pTM ) -> tm_year + i1900 ; ( pSYTM ) -> tm_yday = ( pTM ) -> tm_yday ; ( pSYTM ) -> tm_wday = ( pTM ) -> tm_wday ; ( pSYTM ) -> tm_isdst = ( pTM ) -> tm_isdst ; ( pSYTM ) -> tm_gmtoff = i0 ; ( pSYTM ) -> tm_zone = i0 ;"
#   Warning: Could not parse macro "#define SYSTEMTIME_TO_SYTM(pSYSTIME,pSYTM) ( pSYTM ) -> tm_hour = ( pSYSTIME ) -> wHour ; ( pSYTM ) -> tm_min = ( pSYSTIME ) -> wMinute ; ( pSYTM ) -> tm_sec = ( pSYSTIME ) -> wSecond ; ( pSYTM ) -> tm_mon = ( pSYSTIME ) -> wMonth - i1 ; ( pSYTM ) -> tm_mday = ( pSYSTIME ) -> wDay ; ( pSYTM ) -> tm_year = ( pSYSTIME ) -> wYear ; ( pSYTM ) -> tm_yday = i0 ; ( pSYTM ) -> tm_wday = ( pSYSTIME ) -> wDayOfWeek ; ( pSYTM ) -> tm_gmtoff = i0 ; ( pSYTM ) -> tm_isdst = - i1 ; ( pSYTM ) -> tm_zone = i0 ;"
#   Warning: Macro "UNQLITE_APIEXPORT" depends on an unknown identifier "SX_APIEXPORT". Macro "UNQLITE_APIEXPORT" will not be output
#   Status: Writing to c:\users\cpu101~1\appdata\local\temp\pip-build-vsll6e\unqlite\unqlite\_unqlite.py.
#   Status: Wrapping complete.
#   creating build
#   creating build\lib.win32-2.7
#   creating build\lib.win32-2.7\unqlite
#   copying unqlite\core.py -> build\lib.win32-2.7\unqlite
#   copying unqlite\tests.py -> build\lib.win32-2.7\unqlite
#   copying unqlite\_unqlite.py -> build\lib.win32-2.7\unqlite
#   copying unqlite\__init__.py -> build\lib.win32-2.7\unqlite
#   creating build\lib.win32-2.7\ctypesgen
#   copying ctypesgen\ctypesgen.py -> build\lib.win32-2.7\ctypesgen
#   copying ctypesgen\__init__.py -> build\lib.win32-2.7\ctypesgen
#   creating build\lib.win32-2.7\ctypesgen\ctypesgencore
#   copying ctypesgen\ctypesgencore\ctypedescs.py -> build\lib.win32-2.7\ctypesgen\ctypesgencore
#   copying ctypesgen\ctypesgencore\descriptions.py -> build\lib.win32-2.7\ctypesgen\ctypesgencore
#   copying ctypesgen\ctypesgencore\expressions.py -> build\lib.win32-2.7\ctypesgen\ctypesgencore
#   copying ctypesgen\ctypesgencore\libraryloader.py -> build\lib.win32-2.7\ctypesgen\ctypesgencore
#   copying ctypesgen\ctypesgencore\messages.py -> build\lib.win32-2.7\ctypesgen\ctypesgencore
#   copying ctypesgen\ctypesgencore\old libraryloader.py -> build\lib.win32-2.7\ctypesgen\ctypesgencore
#   copying ctypesgen\ctypesgencore\options.py -> build\lib.win32-2.7\ctypesgen\ctypesgencore
#   copying ctypesgen\ctypesgencore\__init__.py -> build\lib.win32-2.7\ctypesgen\ctypesgencore
#   creating build\lib.win32-2.7\ctypesgen\ctypesgencore\parser
#   copying ctypesgen\ctypesgencore\parser\cdeclarations.py -> build\lib.win32-2.7\ctypesgen\ctypesgencore\parser
#   copying ctypesgen\ctypesgencore\parser\cgrammar.py -> build\lib.win32-2.7\ctypesgen\ctypesgencore\parser
#   copying ctypesgen\ctypesgencore\parser\cparser.py -> build\lib.win32-2.7\ctypesgen\ctypesgencore\parser
#   copying ctypesgen\ctypesgencore\parser\ctypesparser.py -> build\lib.win32-2.7\ctypesgen\ctypesgencore\parser
#   copying ctypesgen\ctypesgencore\parser\datacollectingparser.py -> build\lib.win32-2.7\ctypesgen\ctypesgencore\parser
#   copying ctypesgen\ctypesgencore\parser\lex.py -> build\lib.win32-2.7\ctypesgen\ctypesgencore\parser
#   copying ctypesgen\ctypesgencore\parser\lextab.py -> build\lib.win32-2.7\ctypesgen\ctypesgencore\parser
#   copying ctypesgen\ctypesgencore\parser\parsetab.py -> build\lib.win32-2.7\ctypesgen\ctypesgencore\parser
#   copying ctypesgen\ctypesgencore\parser\pplexer.py -> build\lib.win32-2.7\ctypesgen\ctypesgencore\parser
#   copying ctypesgen\ctypesgencore\parser\preprocessor.py -> build\lib.win32-2.7\ctypesgen\ctypesgencore\parser
#   copying ctypesgen\ctypesgencore\parser\yacc.py -> build\lib.win32-2.7\ctypesgen\ctypesgencore\parser
#   copying ctypesgen\ctypesgencore\parser\__init__.py -> build\lib.win32-2.7\ctypesgen\ctypesgencore\parser
#   creating build\lib.win32-2.7\ctypesgen\ctypesgencore\printer
#   copying ctypesgen\ctypesgencore\printer\defaultheader.py -> build\lib.win32-2.7\ctypesgen\ctypesgencore\printer
#   copying ctypesgen\ctypesgencore\printer\preamble.py -> build\lib.win32-2.7\ctypesgen\ctypesgencore\printer
#   copying ctypesgen\ctypesgencore\printer\printer.py -> build\lib.win32-2.7\ctypesgen\ctypesgencore\printer
#   copying ctypesgen\ctypesgencore\printer\test.py -> build\lib.win32-2.7\ctypesgen\ctypesgencore\printer
#   copying ctypesgen\ctypesgencore\printer\__init__.py -> build\lib.win32-2.7\ctypesgen\ctypesgencore\printer
#   creating build\lib.win32-2.7\ctypesgen\ctypesgencore\processor
#   copying ctypesgen\ctypesgencore\processor\dependencies.py -> build\lib.win32-2.7\ctypesgen\ctypesgencore\processor
#   copying ctypesgen\ctypesgencore\processor\operations.py -> build\lib.win32-2.7\ctypesgen\ctypesgencore\processor
#   copying ctypesgen\ctypesgencore\processor\pipeline.py -> build\lib.win32-2.7\ctypesgen\ctypesgencore\processor
#   copying ctypesgen\ctypesgencore\processor\__init__.py -> build\lib.win32-2.7\ctypesgen\ctypesgencore\processor
#   creating build\lib.win32-2.7\unqlite\src
#   copying unqlite\src\unqlite.c -> build\lib.win32-2.7\unqlite\src
#   copying unqlite\src\unqlite.h -> build\lib.win32-2.7\unqlite\src
#   running build_ext
#   building 'unqlite.libunqlite' extension
#   creating build\temp.win32-2.7
#   creating build\temp.win32-2.7\Release
#   creating build\temp.win32-2.7\Release\unqlite
#   creating build\temp.win32-2.7\Release\unqlite\src
#   C:\Users\CPU10157-local\AppData\Local\Programs\Common\Microsoft\Visual C++ for Python\9.0\VC\Bin\cl.exe /c /nologo /Ox /MD /W3 /GS- /DNDEBUG -DUNQLITE_ENABLE_THREADS=1 -ID:\tools\python2\include -ID:\tools\python2\PC /Tcunqlite/src/unqlite.c /Fobuild\temp.win32-2.7\Release\unqlite/src/unqlite.obj
#   unqlite.c
#   unqlite/src/unqlite.c(50649) : warning C4244: 'initializing' : conversion from 'sxu64' to 'sxu16', possible loss of data
#   C:\Users\CPU10157-local\AppData\Local\Programs\Common\Microsoft\Visual C++ for Python\9.0\VC\Bin\link.exe /DLL /nologo /INCREMENTAL:NO /LIBPATH:D:\tools\python2\libs /LIBPATH:D:\tools\python2\PCbuild /EXPORT:initlibunqlite build\temp.win32-2.7\Release\unqlite/src/unqlite.obj /OUT:build\lib.win32-2.7\unqlite\libunqlite.pyd /IMPLIB:build\temp.win32-2.7\Release\unqlite/src\libunqlite.lib /MANIFESTFILE:build\temp.win32-2.7\Release\unqlite/src\libunqlite.pyd.manifest
#   LINK : error LNK2001: unresolved external symbol initlibunqlite
#   build\temp.win32-2.7\Release\unqlite/src\libunqlite.lib : fatal error LNK1120: 1 unresolved externals
#   error: command 'C:\\Users\\CPU10157-local\\AppData\\Local\\Programs\\Common\\Microsoft\\Visual C++ for Python\\9.0\\VC\\Bin\\link.exe' failed with exit status 1120
#
#   ----------------------------------------
# Failed to build unqlite
# Installing collected packages: unqlite
#   Running setup.py install for unqlite
# Successfully installed unqlite-0.2.0

# %% [markdown]
# ## Time
# ### Nanotime

# %%
import time
import datetime as datetime_module
import calendar


__author__ = 'jbenet@cs.stanford.edu'
__version__ = '0.5.2'


__doc__ = '''
The nanotime module provides a time object that keeps time as the number of
nanoseconds since the UNIX epoch. In other words, it is a UNIX timestamp with
nanosecond precision.
It's base type is a 64bit integer (for network use).
'''

class nanotime(object):

  def __init__(self, nanoseconds):
    if isinstance(nanoseconds, self.__class__):
      self._ns = nanoseconds._ns
    elif isinstance(nanoseconds, int):
      self._ns = nanoseconds
    else:
      self._ns = int(round(nanoseconds))

  #----------------------------------------------------
  def days(self):
    return self._ns / (1.0e9 * 60 * 60 * 24)

  def hours(self):
    return self._ns / (1.0e9 * 60 * 60)

  def minutes(self):
    return self._ns / (1.0e9 * 60)

  def seconds(self):
    return self._ns / 1.0e9

  def milliseconds(self):
    return self._ns / 1.0e6

  def microseconds(self):
    return self._ns / 1.0e3

  def nanoseconds(self):
    return self._ns

  #----------------------------------------------------

  def unixtime(self):
    return self.timestamp()

  def timestamp(self):
    if hasattr(self, '_timestamp'):
      return self._timestamp
    return self.seconds()

  def datetime(self):
    if hasattr(self, '_datetime'):
      return self._datetime
    return datetime_module.datetime.fromtimestamp(self.timestamp())

  #----------------------------------------------------

  def __int__(self):
    return self._ns

  def __str__(self):
    frac = str(self._ns)[-9:]
    # when microseconds == 000000, datetime doesnt print them.
    if frac[:6] == '000000':
      return '%s.%s' % (self.datetime(), frac)
    return '%s%s' % (self.datetime(), frac[-3:])

  def __repr__(self):
    return 'nanotime.nanotime(%d)' % self._ns

  #----------------------------------------------------

  def __add__(self, other):
    return self.__class__(self._ns + other._ns)

  def __sub__(self, other):
    return self.__class__(self._ns - other._ns)

  def __mul__(self, other):
    return self.__class__(self._ns * other._ns)

  def __div__(self, other):
    return self.__class__(self._ns * 1.0 / other._ns)

  def __cmp__(self, other):
    '''Attempt to convert other types'''
    if isinstance(other, self.__class__):
      return cmp(self._ns, other._ns)
    else:
      return cmp(self._ns, _converter.convert(other)._ns)

  def __hash__(self):
    return hash(self._ns)

  @classmethod
  def now(cls):
    return _converter.now()


class _converter(object):

  @classmethod
  def days(cls, m):
    return nanotime(m * 1000000000 * 60 * 60 * 24)

  @classmethod
  def hours(cls, m):
    return nanotime(m * 1000000000 * 60 * 60)

  @classmethod
  def minutes(cls, m):
    return nanotime(m * 1000000000 * 60)

  @classmethod
  def seconds(cls, s):
    return nanotime(s * 1000000000)

  @classmethod
  def milliseconds(cls, ms):
    return nanotime(ms * 1000000)

  @classmethod
  def microseconds(cls, us):
    return nanotime(us * 1000)

  @classmethod
  def nanoseconds(cls, ns):
    return nanotime(ns)

  #----------------------------------------------------

  @classmethod
  def unixtime(cls, unixtime):
    return cls.timestamp(unixtime)

  @classmethod
  def timestamp(cls, ts):
    nt = cls.seconds(ts)
    nt._timestamp = ts
    return nt

  @classmethod
  def datetime(cls, d):
    du = d if d.utcoffset() is None else d - d.utcoffset()
    us = int(calendar.timegm(du.timetuple()) * 1000000 + du.microsecond)
    nt = cls.microseconds(us)
    nt._datetime = d
    return nt

  #----------------------------------------------------

  @classmethod
  def now(cls):
    return cls.seconds(time.time())

  @classmethod
  def convert(cls, other):
    if isinstance(other, datetime_module.datetime):
      return cls.datetime(other)
    elif isinstance(other, float):
      return cls.timestamp(other)
    elif isinstance(other, int) or isinstance(other, long):
      return cls.nanoseconds(other)
    else:
      raise TypeError('Cannot convert %s into %s' % (type(other), nanotime))


days = _converter.days
hours = _converter.hours
minutes = _converter.minutes
seconds = _converter.seconds
milliseconds = _converter.milliseconds
microseconds = _converter.microseconds
nanoseconds = _converter.nanoseconds
unixtime = _converter.unixtime
timestamp = _converter.timestamp
datetime = _converter.datetime
convert = _converter.convert
now = _converter.now

# %% [markdown]
# ### Measure time
