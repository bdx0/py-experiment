# %% [markdown]
# ### webrtc stats
#
# - https://tech.appear.in/2015/05/25/Introduction-to-WebRTC-on-Android/
# - http://googletesting.blogspot.com/2013/11/webrtc-audio-quality-testing.html
# - http://googletesting.blogspot.com/2013/11/webrtc-audio-quality-testing.html
# - http://tools.ietf.org/html/draft-alvestrand-rtcweb-congestion-03#section-1.1
# - http://customer.xfinity.com/help-and-support/internet/network-management-information
# - http://www.voiptroubleshooter.com/basics/index.html
# - http://www.voiptroubleshooter.com/basics/predep.html
# - http://www.voiptroubleshooter.com/indepth/jittersources.html
# - http://www.voiptroubleshooter.com/indepth/burstloss.html
# - http://www.callstats.io/api/
# - https://bloggeek.me/callstatsio-webrtc-interview/
# - https://tools.ietf.org/html/rfc6464
# - https://tools.ietf.org/html/rfc4585
# - https://webrtcglossary.com/p2p/
# - https://appliedtech.iit.edu/rtc-lab
# - http://www.rtc-conference.com/category/news/
# - http://www.w3.org/2011/04/webrtc/wiki/images/7/75/TPAC_2013_stats.pdf
# - http://www.w3.org/TR/2015/WD-webrtc-stats-20150206/#widl-RTCMediaStreamTrackStats-audioLevel

# %%
from IPython.core.display import HTML
HTML('''<html>
        <head>
             <script type="text/javascript" src="http://code.jquery.com/jquery-2.1.1.min.js"></script>
        </head>
        <body onresize="$('#iframe1').attr('height', $(window).height());" style="margin:0;" >
            <iframe id="iframe1" src="%s" style="width:100%%;"  onload="this.height=$(window).height();"></iframe>
        </body>
        </html>
        ''' % "https://docs.google.com/document/d/13VpasxmZvcRShdwEg0AvOh2nqSnQsB_tHWrKOv6E4CA/edit")
# Out:
# <html>
#         <head>
#              <script type="text/javascript" src="http://code.jquery.com/jquery-2.1.1.min.js"></script>
#         </head>
#         <body onresize="$('#iframe1').attr('height', $(window).height());" style="margin:0;" >
#             <iframe id="iframe1" src="https://docs.google.com/document/d/13VpasxmZvcRShdwEg0AvOh2nqSnQsB_tHWrKOv6E4CA/edit" style="width:100%;"  onload="this.height=$(window).height();"></iframe>
#         </body>
#         </html>

# %%
from IPython.core.display import HTML
HTML('''<html>
        <head>
             <script type="text/javascript" src="http://code.jquery.com/jquery-2.1.1.min.js"></script>
        </head>
        <body onresize="$('#iframe1').attr('height', $(window).height());" style="margin:0;" >
            <iframe id="iframe1" src="%s" style="width:100%%;"  onload="this.height=$(window).height();"></iframe>
        </body>
        </html>
        ''' % "https://docs.google.com/document/d/13VpasxmZvcRShdwEg0AvOh2nqSnQsB_tHWrKOv6E4CA/edit")
# Out:
# <html>
#         <head>
#              <script type="text/javascript" src="http://code.jquery.com/jquery-2.1.1.min.js"></script>
#         </head>
#         <body onresize="$('#iframe1').attr('height', $(window).height());" style="margin:0;" >
#             <iframe id="iframe1" src="https://docs.google.com/document/d/13VpasxmZvcRShdwEg0AvOh2nqSnQsB_tHWrKOv6E4CA/edit" style="width:100%;"  onload="this.height=$(window).height();"></iframe>
#         </body>
#         </html>

# %%
from IPython.core.display import HTML
HTML('''<html>
        <head>
             <script type="text/javascript" src="http://code.jquery.com/jquery-2.1.1.min.js"></script>
        </head>
        <body onresize="$('#iframe1').attr('height', $(window).height());" style="margin:0;" >
            <iframe id="iframe1" src="%s" style="width:100%%;"  onload="this.height=$(window).height();"></iframe>
        </body>
        </html>
        ''' % "https://docs.google.com/spreadsheets/d/1LpT0DSNZnFMSkkASmz29PpmuBToG8Q8ubBADvG16RqM/edit#gid=0")
# Out:
# <html>
#         <head>
#              <script type="text/javascript" src="http://code.jquery.com/jquery-2.1.1.min.js"></script>
#         </head>
#         <body onresize="$('#iframe1').attr('height', $(window).height());" style="margin:0;" >
#             <iframe id="iframe1" src="https://docs.google.com/spreadsheets/d/1LpT0DSNZnFMSkkASmz29PpmuBToG8Q8ubBADvG16RqM/edit#gid=0" style="width:100%;"  onload="this.height=$(window).height();"></iframe>
#         </body>
#         </html>

# %%
from IPython.core.display import HTML
HTML('''<html>
        <head>
             <script type="text/javascript" src="http://code.jquery.com/jquery-2.1.1.min.js"></script>
        </head>
        <body onresize="$('#iframe1').attr('height', $(window).height());" style="margin:0;" >
            <iframe id="iframe1" src="%s" style="width:100%%;"  onload="this.height=$(window).height();"></iframe>
        </body>
        </html>
        ''' % "http://nbviewer.ipython.org/github/markdregan/K-Nearest-Neighbors-with-Dynamic-Time-Warping/blob/master/K_Nearest_Neighbor_Dynamic_Time_Warping.ipynb")
# Out:
# <html>
#         <head>
#              <script type="text/javascript" src="http://code.jquery.com/jquery-2.1.1.min.js"></script>
#         </head>
#         <body onresize="$('#iframe1').attr('height', $(window).height());" style="margin:0;" >
#             <iframe id="iframe1" src="http://nbviewer.ipython.org/github/markdregan/K-Nearest-Neighbors-with-Dynamic-Time-Warping/blob/master/K_Nearest_Neighbor_Dynamic_Time_Warping.ipynb" style="width:100%;"  onload="this.height=$(window).height();"></iframe>
#         </body>
#         </html>

# %%
from IPython.core.display import HTML
HTML('''<html>
        <head>
             <script type="text/javascript" src="http://code.jquery.com/jquery-2.1.1.min.js"></script>
        </head>
        <body onresize="$('#iframe1').attr('height', $(window).height());" style="margin:0;" >
            <iframe id="iframe1" src="%s" style="width:100%%;"  onload="this.height=$(window).height();"></iframe>
        </body>
        </html>
        ''' % "http://nbviewer.ipython.org/github/unpingco/Python-for-Signal-Processing/blob/master/Compressive_Sampling.ipynb")
# Out:
# <html>
#         <head>
#              <script type="text/javascript" src="http://code.jquery.com/jquery-2.1.1.min.js"></script>
#         </head>
#         <body onresize="$('#iframe1').attr('height', $(window).height());" style="margin:0;" >
#             <iframe id="iframe1" src="http://nbviewer.ipython.org/github/unpingco/Python-for-Signal-Processing/blob/master/Compressive_Sampling.ipynb" style="width:100%;"  onload="this.height=$(window).height();"></iframe>
#         </body>
#         </html>

# %%
from IPython.core.display import HTML
HTML('''<html>
        <head>
             <script type="text/javascript" src="http://code.jquery.com/jquery-2.1.1.min.js"></script>
        </head>
        <body onresize="$('#iframe1').attr('height', $(window).height());" style="margin:0;" >
            <iframe id="iframe1" src="%s" style="width:100%%;"  onload="this.height=$(window).height();"></iframe>
        </body>
        </html>
        ''' % "http://nbviewer.ipython.org/github/rlabbe/Kalman-and-Bayesian-Filters-in-Python/blob/master/table_of_contents.ipynb")

# %%
#https://github.com/plotly/widgets

# %%
# %%HTML
# <div style="display: inline;
#             width: 300px;
#             float: left;
#             margin-top: 68px;">
#     Plot this table!<br>
#     Click to edit the numbers in the grid.
#     <table class="pure-table" >
#         <thead>
#             <tr>
#                 <th>X<sub>1</sub></th>
#                 <th>Y<sub>1</sub></th>
#                 <th>X<sub>2</sub></th>
#                 <th>Y<sub>2</sub></th>
#             </tr>
#         </thead>
#
#         <tbody>
#             <tr>
#                 <td class="x1">1</td>
#                 <td class="y1">10</td>
#
#                 <td class="x2">1</td>
#                 <td class="y2">16</td>
#             </tr>
#
#             <tr>
#                 <td class="x1">2</td>
#                 <td class="y1">15</td>
#
#                 <td class="x2">2</td>
#                 <td class="y2">5</td>
#             </tr>
#
#             <tr>
#                 <td class="x1">3</td>
#                 <td class="y1">13</td>
#
#                 <td class="x2">3</td>
#                 <td class="y2">11</td>
#             </tr>
#
#             <tr>
#                 <td class="x1">4</td>
#                 <td class="y1">17</td>
#
#                 <td class="x2">4</td>
#                 <td class="y2">9</td>
#             </tr>
#         </tbody>
#     </table>
# </div>
#
# <iframe id="igraph" scrolling="no" style="border:none; display:inline-block;" seamless="seamless"
#          src="https://plot.ly/~chris/3287.embed" height="600" width="600"></iframe>
#
# <script src="https://ajax.googleapis.com/ajax/libs/jquery/1.11.1/jquery.min.js"></script>
# <script src="https://rawgit.com/mindmup/editable-table/master/mindmup-editabletable.js"></script>
#
# <script type="text/Javascript">
#     window.removeEventListener('message');
#     if(typeof(pinger) !== 'undefined') {
#         clearInterval(pinger);
#     }
#     var plot = $('#igraph')[0].contentWindow;
#     var pinger = setInterval(function(){
#         console.log('posting ping');
#         plot.postMessage({ping: true}, 'https://plot.ly');
#     }, 5000);
#     window.addEventListener('message', function(e) {
#         var message = e.data;
#         if(message==='pong') {
#             clearInterval(pinger);
#             $('table').editableTableWidget();
#             $('table td').on('change', function(evt, newValue) {
#                 // do something with the new cell value
#                 var x1 = [],
#                     y1 = [],
#                     x2 = [],
#                     y2 = [];
#                 $('.x1').each(function(index){
#                     x1.push($(this).text());
#                 });
#                 $('.y1').each(function(index){
#                     y1.push($(this).text());
#                 });
#                 $('.x2').each(function(index){
#                     x2.push($(this).text());
#                 });
#                 $('.y2').each(function(index){
#                     y2.push($(this).text());
#                 });
#                 plot.postMessage({restyle: {'x': [x1, x2], 'y': [y1, y2]}}, 'https://plot.ly')
#             });
#         }
#     });
# </script>
#
# <link rel="stylesheet" href="http://yui.yahooapis.com/pure/0.5.0/pure-min.css">
# Out:
# <div style="display: inline;
#             width: 300px;
#             float: left;
#             margin-top: 68px;">
#     Plot this table!<br>
#     Click to edit the numbers in the grid.
#     <table class="pure-table" >
#         <thead>
#             <tr>
#                 <th>X<sub>1</sub></th>
#                 <th>Y<sub>1</sub></th>
#                 <th>X<sub>2</sub></th>
#                 <th>Y<sub>2</sub></th>
#             </tr>
#         </thead>
#
#         <tbody>
#             <tr>
#                 <td class="x1">1</td>
#                 <td class="y1">10</td>
#
#                 <td class="x2">1</td>
#                 <td class="y2">16</td>
#             </tr>
#
#             <tr>
#                 <td class="x1">2</td>
#                 <td class="y1">15</td>
#
#                 <td class="x2">2</td>
#                 <td class="y2">5</td>
#             </tr>
#
#             <tr>
#                 <td class="x1">3</td>
#                 <td class="y1">13</td>
#
# ...

# %%
from sklearn.neighbors.kde import KernelDensity
import numpy as np
X = np.array([[-1, -1], [-2, -1], [-3, -2], [1, 1], [2, 1], [3, 2]])
kde = KernelDensity(kernel='gaussian', bandwidth=0.2).fit(X)
kde.score_samples(X)
# Out:
# array([-0.41075698, -0.41075698, -0.41076071, -0.41075698, -0.41075698,
#        -0.41076071])

# %% [markdown]
# ## http://jakevdp.github.io/blog/2013/05/19/a-javascript-viewer-for-matplotlib-animations/

# %%
import os
import sys
current_path = %pwd
# os.environ['PYTHONPATH'] = current_path + '\JSAnimation;' + os.environ['PYTHONPATH']  
# os.environ['PYTHONPATH'] = current_path + '\ipywidgets;' + os.environ['PYTHONPATH'] 
#sys.path.append(current_path + '\JSAnimation')
#sys.path.append(current_path + '\ipywidgets')

# print os.environ['PYTHONPATH'] 
# print sys.path

# %%
from matplotlib import animation
from JSAnimation import IPython_display

fig = plt.figure()
ax = plt.axes(xlim=(0, 10), ylim=(-2, 2))
line, = ax.plot([], [], lw=2)

def init():
    line.set_data([], [])
    return line,

def animate(i):
    x = np.linspace(0, 10, 1000)
    y = np.cos(i * 0.02 * np.pi) * np.sin(x - i * 0.02 * np.pi)
    line.set_data(x, y)
    return line,

animation.FuncAnimation(fig, animate, init_func=init,
                        frames=100, interval=30)
# Out:
# <script language="javascript">
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     document.getElementById(this.slider_id).max = this.frames.length - 1;
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
# ...

# %%
# !ls -la D:\dbduy0206\py-experiment\src\iby-notebook\signal_processing\JSAnimation\JSAnimation
# Out:
# total 33
# drwxr-xr-x 1 CPU10157-local None     0 Jun 11 16:50 .
# drwxr-xr-x 1 CPU10157-local None     0 Jun 11 16:50 ..
# -rw-r--r-- 1 CPU10157-local None  3122 Jun 11 16:50 IPython_display.py
# -rw-r--r-- 1 CPU10157-local None    37 Jun 11 16:50 __init__.py
# -rw-r--r-- 1 CPU10157-local None  3223 Jun 11 16:50 examples.py
# -rw-r--r-- 1 CPU10157-local None 11511 Jun 11 16:50 html_writer.py
# drwxr-xr-x 1 CPU10157-local None     0 Jun 11 16:50 icons

# %%
from matplotlib import matplotlib as plt
fig, ax = plt.subplots()
ax.plot(random.rand(100))
# write the figure to a temporary file, and encode the results to base64
import tempfile
with tempfile.NamedTemporaryFile(suffix='.png') as f:
    fig.savefig(f.name)
    data = open(f.name, 'rb').read().encode('base64')
    
# close the figure and display the data
plt.close(fig)
print data[:460]
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-27-a2f11f5fe7da> in <module>()
# ----> 1 from matplotlib import matplotlib as plt
#       2 fig, ax = plt.subplots()
#       3 ax.plot(random.rand(100))
#       4 # write the figure to a temporary file, and encode the results to base64
#       5 import tempfile
#
# ImportError: cannot import name matplotlib

# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
from tempfile import NamedTemporaryFile

VIDEO_TAG = """<video controls>
 <source src="data:video/x-m4v;base64,{0}" type="video/mp4">
 Your browser does not support the video tag.
</video>"""

def anim_to_html(anim):
    if not hasattr(anim, '_encoded_video'):
        with NamedTemporaryFile(suffix='.mp4') as f:
            anim.save(f.name, fps=20, extra_args=['-vcodec', 'libx264'])
            video = open(f.name, "rb").read()
        anim._encoded_video = video.encode("base64")
    
    return VIDEO_TAG.format(anim._encoded_video)

# %%
from IPython.display import HTML

def display_animation(anim):
    plt.close(anim._fig)
    return HTML(anim_to_html(anim))

# %%
from matplotlib import animation

# First set up the figure, the axis, and the plot element we want to animate
fig = plt.figure()
ax = plt.axes(xlim=(0, 2), ylim=(-2, 2))
line, = ax.plot([], [], lw=2)

# initialization function: plot the background of each frame
def init():
    line.set_data([], [])
    return line,

# animation function.  This is called sequentially
def animate(i):
    x = np.linspace(0, 2, 1000)
    y = np.sin(2 * np.pi * (x - 0.01 * i))
    line.set_data(x, y)
    return line,

# call the animator.  blit=True means only re-draw the parts that have changed.
anim = animation.FuncAnimation(fig, animate, init_func=init,
                               frames=100, interval=20, blit=True)

# call our new function to display the animation
display_animation(anim)
# Out:
# D:\tools\python2\lib\site-packages\matplotlib\animation.py:742: UserWarning: MovieWriter ffmpeg unavailable
#   warnings.warn("MovieWriter %s unavailable" % writer)
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-32-b51bfc0123f6> in <module>()
#      23
#      24 # call our new function to display the animation
# ---> 25 display_animation(anim)
#
# <ipython-input-31-63a8cd04f4be> in display_animation(anim)
#       3 def display_animation(anim):
#       4     plt.close(anim._fig)
# ----> 5     return HTML(anim_to_html(anim))
#
# <ipython-input-29-e4c246e992b2> in anim_to_html(anim)
#       9     if not hasattr(anim, '_encoded_video'):
#      10         with NamedTemporaryFile(suffix='.mp4') as f:
# ---> 11             anim.save(f.name, fps=20, extra_args=['-vcodec', 'libx264'])
#      12             video = open(f.name, "rb").read()
# ...
